# %%
import pandas as pd
from nba_api.stats.endpoints import playbyplayv2
from nba_api.stats.library.eventmsgtype import EventMsgType
from nba_api.stats.library.playbyplayregex import re_block, re_field_goal_made, re_field_goal_missed

# %%
pbp = playbyplayv2.PlayByPlayV2(game_id="0021500295")

# %%
df: pd.DataFrame = pbp.get_data_frames()[0]

# Remove everything besides shots
df = df[df["EVENTMSGTYPE"].isin([EventMsgType.FIELD_GOAL_MADE.value, EventMsgType.FIELD_GOAL_MISSED.value])]

# %%
# Based on https://github.com/swar/nba_api/blob/master/docs/examples/PlayByPlay.ipynb
# Rewritten with vectorization to avoid slow loops

df["blocked"] = False
df["blocked_by"] = pd.NA
df.head()
# Out:
#        GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 4   0021500295         4             1                   1       1
# 5   0021500295         5             1                   1       1
# 9   0021500295        11             2                   1       1
# 11  0021500295        13             2                   1       1
# 13  0021500295        15             2                   5       1
#
#    WCTIMESTRING PCTIMESTRING                      HOMEDESCRIPTION  \
# 4       8:43 PM        11:34                                 None
# 5       8:43 PM        11:13  Antetokounmpo 15' Jump Shot (2 PTS)
# 9       8:44 PM        10:49             MISS Monroe 6' Jump Shot
# 11      8:44 PM        10:41                                 None
# 13      8:44 PM        10:34          MISS Antetokounmpo 2' Layup
#
#    NEUTRALDESCRIPTION                            VISITORDESCRIPTION  ...  \
# 4                None  Lopez 11' Jump Shot (2 PTS) (Calderon 1 AST)  ...
# 5                None                                          None  ...
# 9                None                                          None  ...
# 11               None                MISS Anthony 24' 3PT Jump Shot  ...
# 13               None                           Lopez BLOCK (1 BLK)  ...
#
#    PERSON3TYPE PLAYER3_ID  PLAYER3_NAME  PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 4            0          0          None              NaN              None
# 5            0          0          None              NaN              None
# 9            0          0          None              NaN              None
# 11           0          0          None              NaN              None
# 13           5     201577   Robin Lopez     1.610613e+09          New York
#
#     PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  \
# 4                    None                      None                    1
# 5                    None                      None                    1
# 9                    None                      None                    1
# 11                   None                      None                    1
# 13                 Knicks                       NYK                    1
#
#    blocked  blocked_by
# 4    False        <NA>
# 5    False        <NA>
# 9    False        <NA>
# 11   False        <NA>
# 13   False        <NA>
#
# [5 rows x 36 columns]

# %%
# This will tell us which description to look inside
df.loc[(df["HOMEDESCRIPTION"].notnull()) & (df["HOMEDESCRIPTION"].str.match(re_block)), ["blocked", "blocked_by"]] = [True, "HOME"]
df.loc[(df["VISITORDESCRIPTION"].notnull()) & (df["VISITORDESCRIPTION"].str.match(re_block)), ["blocked", "blocked_by"]] = [True, "VISITOR"]

# Replace "HOME" and "VISITOR" with the player name (can we combine this with the above?)
df.loc[(df["blocked_by"] == "HOME"), ["blocked_by"]] = df["HOMEDESCRIPTION"].str.extract(re_block)["player"]
df.loc[(df["blocked_by"] == "VISITOR"), ["blocked_by"]] = df["VISITORDESCRIPTION"].str.extract(re_block)["player"]
df
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 4    0021500295         4             1                   1       1
# 5    0021500295         5             1                   1       1
# 9    0021500295        11             2                   1       1
# 11   0021500295        13             2                   1       1
# 13   0021500295        15             2                   5       1
# ..          ...       ...           ...                 ...     ...
# 442  0021500295       516             2                   1       4
# 444  0021500295       518             1                  42       4
# 445  0021500295       519             2                   1       4
# 455  0021500295       530             2                   5       4
# 457  0021500295       532             2                   7       4
#
#     WCTIMESTRING PCTIMESTRING  \
# 4        8:43 PM        11:34
# 5        8:43 PM        11:13
# 9        8:44 PM        10:49
# 11       8:44 PM        10:41
# 13       8:44 PM        10:34
# ..           ...          ...
# 442     10:50 PM         1:37
# 444     10:50 PM         1:15
# 445     10:50 PM         1:07
# 455     10:52 PM         0:39
# 457     10:52 PM         0:22
#
#                                        HOMEDESCRIPTION NEUTRALDESCRIPTION  \
# 4                                                 None               None
# 5                  Antetokounmpo 15' Jump Shot (2 PTS)               None
# 9                             MISS Monroe 6' Jump Shot               None
# 11                                                None               None
# 13                         MISS Antetokounmpo 2' Layup               None
# ..                                                 ...                ...
# 442                                               None               None
# 444  Antetokounmpo 1' Driving Layup (16 PTS) (Middl...               None
# 445                        Antetokounmpo BLOCK (2 BLK)               None
# 455                               Monroe BLOCK (1 BLK)               None
# 457                           MISS Antetokounmpo  Dunk               None
#
#                                VISITORDESCRIPTION  ... PERSON3TYPE PLAYER3_ID  \
# 4    Lopez 11' Jump Shot (2 PTS) (Calderon 1 AST)  ...           0          0
# 5                                            None  ...           0          0
# 9                                            None  ...           0          0
# 11                 MISS Anthony 24' 3PT Jump Shot  ...           0          0
# 13                            Lopez BLOCK (1 BLK)  ...           5     201577
# ..                                            ...  ...         ...        ...
# 442                  MISS Grant 26' 3PT Jump Shot  ...           0          0
# 444                                          None  ...           0          0
# 445                       MISS Grant 3' Jump Shot  ...           4     203507
# 455                           MISS Grant 3' Layup  ...           4     202328
# 457                                          None  ...           0          0
#
#               PLAYER3_NAME  PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 4                     None              NaN              None
# 5                     None              NaN              None
# 9                     None              NaN              None
# 11                    None              NaN              None
# 13             Robin Lopez     1.610613e+09          New York
# ..                     ...              ...               ...
# 442                   None              NaN              None
# 444                   None              NaN              None
# 445  Giannis Antetokounmpo     1.610613e+09         Milwaukee
# 455            Greg Monroe     1.610613e+09         Milwaukee
# 457                   None              NaN              None
#
#      PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION VIDEO_AVAILABLE_FLAG  \
# 4                     None                      None                    1
# 5                     None                      None                    1
# 9                     None                      None                    1
# 11                    None                      None                    1
# 13                  Knicks                       NYK                    1
# ..                     ...                       ...                  ...
# 442                   None                      None                    1
# 444                   None                      None                    1
# 445                  Bucks                       MIL                    1
# 455                  Bucks                       MIL                    1
# 457                   None                      None                    1
#
#     blocked     blocked_by
# 4     False           <NA>
# 5     False           <NA>
# 9     False           <NA>
# 11    False           <NA>
# 13     True          Lopez
# ..      ...            ...
# 442   False           <NA>
# 444   False           <NA>
# 445    True  Antetokounmpo
# 455    True         Monroe
# 457   False           <NA>
#
# [165 rows x 36 columns]

# %%
# Get shot type using regex on description
# Replace spaces with underscores and capitalize shot type
# We can't do (nonnull()) & (EVENTMSGTYPE == 1) because the other description may be a block
df["shot_type"] = pd.NA
df.loc[(df["HOMEDESCRIPTION"].notnull()) & (df["HOMEDESCRIPTION"].str.match(re_field_goal_made)), ["shot_type"]] = df["HOMEDESCRIPTION"].str.extract(re_field_goal_made)["field_goal_type"].str.rstrip().str.replace(' ', '_').str.upper()
df.loc[(df["HOMEDESCRIPTION"].notnull()) & (df["HOMEDESCRIPTION"].str.match(re_field_goal_missed)), ["shot_type"]] = df["HOMEDESCRIPTION"].str.extract(re_field_goal_missed)["field_goal_type"].str.rstrip().str.replace(' ', '_').str.upper()
df.loc[(df["VISITORDESCRIPTION"].notnull()) & (df["VISITORDESCRIPTION"].str.match(re_field_goal_made)), ["shot_type"]] = df["VISITORDESCRIPTION"].str.extract(re_field_goal_made)["field_goal_type"].str.rstrip().str.replace(' ', '_').str.upper()
df.loc[(df["VISITORDESCRIPTION"].notnull()) & (df["VISITORDESCRIPTION"].str.match(re_field_goal_missed)), ["shot_type"]] = df["VISITORDESCRIPTION"].str.extract(re_field_goal_missed)["field_goal_type"].str.rstrip().str.replace(' ', '_').str.upper()
df.head()
df["shot_type"].unique()
# Out:
# array(['JUMP_SHOT', '3PT_JUMP_SHOT', 'LAYUP', 'RUNNING_LAYUP',
#        'REVERSE_LAYUP', 'TIP_LAYUP_SHOT', 'TURNAROUND_JUMP_SHOT',
#        'HOOK_SHOT', 'FLOATING_JUMP_SHOT', 'DUNK', 'FINGER_ROLL_LAYUP',
#        'DRIVING_LAYUP', 'STEP_BACK_JUMP_SHOT', 'CUTTING_LAYUP_SHOT',
#        'RUNNING_JUMP_SHOT', 'RUNNING_DUNK', 'PUTBACK_LAYUP',
#        'PULLUP_JUMP_SHOT', 'RUNNING_REVERSE_LAYUP',
#        'RUNNING_FINGER_ROLL_LAYUP', 'REVERSE_DUNK', 'FADEAWAY_JUMPER',
#        'DRIVING_REVERSE_LAYUP'], dtype=object)
